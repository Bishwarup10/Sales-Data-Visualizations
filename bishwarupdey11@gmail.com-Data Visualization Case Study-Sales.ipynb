# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sales = pd.read_csv("C:/Users/Bishwarup/Desktop/Analytix Labs/Analytix Labs(Case Study & Assignments)/4.Visualizations(optional)/SalesData.csv")

# %%
sales.head()
# Out:
#    AccountId AccountName Region     Division       City State Tier Month  \
# 0       1116    Account1   West  DIAMONDBACK  PHOENIX W    AZ  Low   Aug
# 1       1116    Account1   West  DIAMONDBACK  PHOENIX W    AZ  Low   Oct
# 2       2391    Account2   East    MINUTEMEN   HARTFORD    CT  Med   Jun
# 3       2391    Account2   East    MINUTEMEN   HARTFORD    CT  Med   Mar
# 4       2397    Account3   East    MINUTEMEN  WORCESTER    MA  Med   Sep
#
#    Sales2015  Sales2016  Units2015  Units2016  TargetAchevied2015  \
# 0       0.00   13208.52        0.0        4.0                0.70
# 1   10500.78   23114.91        3.0        7.0                0.84
# 2       0.00    6627.00        0.0        3.0                1.15
# 3   19881.00   13254.00        9.0        6.0                1.33
# 4    3684.48       0.00        1.0        0.0                1.02
#
#    TargetAchevied2016
# 0                1.53
# 1                1.31
# 2                1.29
# 3                1.17
# ...

# %% [markdown]
# ### 1. Compare Sales by region for 2016 with 2015 using bar chart

# %%
# sales1 = sales.groupby(['...']).aggregate(...) or .agg(..)
sales1=sales.groupby("Region")["Sales2015","Sales2016"].sum()
sales1graph=sales1.plot.bar(figsize=(12,6))
# Out:
# <ipython-input-4-bdbd79acc9b0>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales1=sales.groupby("Region")["Sales2015","Sales2016"].sum()

# %% [markdown]
# ### 2. What are the contributing factors to the sales for each region in 2016. Visualize it using a Pie Chart.

# %%
# sales2 = sales.groupby(['...']).aggregate({})
sales2= sales.groupby("Region")["Sales2016"].sum()
sales2.plot(kind='pie', 
            labels=["Central","East","West"], 
            colors=['r', 'g', 'b'],
            autopct='%1.0f%%', # to get percentage and round off appropriately
            fontsize=10, 
            subplots='true')
# Out:
# array([<AxesSubplot:ylabel='Sales2016'>], dtype=object)

# %% [markdown]
# ### 3. Compare the total sales of 2015 and 2016 with respect to Region and Tiers

# %%
sales3 = sales.groupby(["Region","Tier"]).aggregate({sum})

sales3graph=sales3.plot.bar(figsize=(18,6))

# %%
sales_region_tier = sales.groupby(["Region","Tier"])['Sales2015','Sales2016'].sum()
# Out:
# <ipython-input-7-2ec4a207d357>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_region_tier = sales.groupby(["Region","Tier"])['Sales2015','Sales2016'].sum()

# %%
sales3graph=sales_region_tier.plot.bar(figsize=(18,6))

# %%
#stacked bar chart
sales_region_tier.plot(kind="barh",stacked=True,figsize=(8,8))
plt.xlabel("Sales")
plt.ylabel("Region/Tier")
plt.title("Total sales of 2015 and 2016 with respect to Region and Tiers")
plt.show()

# %% [markdown]
# ### 4. In East region, which state registered a decline in 2016 as compared to 2015?

# %%
#grouping the data based on Region and State to find the total sales in 2015 and 2016
sales4 = sales.groupby(['Region',"State"])['Sales2015','Sales2016'].sum()
# Out:
# <ipython-input-10-322649d8332d>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales4 = sales.groupby(['Region',"State"])['Sales2015','Sales2016'].sum()

# %%
sales4
# Out:
#                   Sales2015     Sales2016
# Region  State
# Central AL     5.091037e+05  5.958284e+05
#         AR     2.133175e+05  2.276081e+05
#         IL     6.217938e+05  7.843074e+05
#         IN     3.166781e+05  5.996723e+05
#         KY     5.312149e+05  6.332189e+05
#         LA     4.793662e+05  6.803033e+05
#         MI     5.686517e+05  7.072480e+05
#         MS     3.045782e+05  2.204109e+05
#         OH     9.276875e+05  1.221085e+06
#         OK     2.484607e+05  3.396445e+05
#         PA     3.002670e+05  2.877924e+05
#         TN     4.370386e+05  5.522301e+05
#         TX     1.712440e+06  2.013116e+06
#         WI     3.044250e+05  4.403802e+05
#         WV     4.167062e+05  4.849640e+05
# East    CT     1.972028e+05  3.235023e+05
#         DC     2.167240e+05  2.574217e+05
#         FL     1.660162e+06  2.508232e+06
#         GA     6.815465e+05  9.469198e+05
#         MA     4.192788e+05  6.870964e+05
#         MD     5.273091e+05  7.500088e+05
# ...

# %%
#filtering out sales for East region in 2015 and 2016 
sales_east = sales4.loc["East"]

# %%
sales_east
# Out:
#          Sales2015   Sales2016
# State
# CT      197202.790   323502.31
# DC      216723.950   257421.69
# FL     1660162.000  2508232.28
# GA      681546.460   946919.77
# MA      419278.750   687096.45
# MD      527309.060   750008.79
# ME       77425.640   183673.05
# NC     1292801.640  1610521.00
# NH      136419.380   144717.51
# NJ      520419.290   782289.19
# NY     1725415.065  1703135.80
# PA      785092.755   894319.49
# RI      156311.800   162454.65
# SC      247811.780   463414.12
# TN       49677.000    70109.41
# VA      819319.130  1179414.94

# %%
sales_east.plot(kind="bar",figsize=(12,8),width=0.8)
plt.ylabel("Sales")
plt.title("Sales comparison between 2015 and 2016 for East Region")
plt.show()

# %%
sales_eastgraph=sales_east.plot.bar(figsize=(12,6))

# %% [markdown]
# ### 5. In all the High tier, which Division saw a decline in number of units sold in 2016 compared to 2015?

# %%
#grouping the data based on tier and division to find the total sum of sales in 2015 and 2016
sales5 =sales.groupby(["Tier","Division"])["Units2015","Units2016"].sum()
# Out:
# <ipython-input-16-94e977989f18>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales5 =sales.groupby(["Tier","Division"])["Units2015","Units2016"].sum()

# %%
high_tier = sales5.loc["High"]

# %%
high_tier.plot(kind="bar",figsize=(12,8),width=0.7)
# Out:
# <AxesSubplot:xlabel='Division'>

# %% [markdown]
# ### 6. Create a new column Qtr using numpy.where() or any suitable utility in the imported dataset. The Quarters are based on months and defined as -
# ### •	Jan - Mar : Q1
#
# ### •	Apr - Jun : Q2
#
# ### •	Jul - Sep : Q3
#
# ### •	Oct - Dec : Q4

# %%
month =sales["Month"]

# %%
month
# Out:
# 0       Aug
# 1       Oct
# 2       Jun
# 3       Mar
# 4       Sep
#        ...
# 3704    Feb
# 3705    Aug
# 3706    Nov
# 3707    Jan
# 3708    Jun
# Name: Month, Length: 3709, dtype: object

# %%
quarter = []
for x in month :
    if x in ["Jan","Feb","Mar"]:
        quarter.append("Q1")
    elif x in ["Apr","May","Jun"]:
        quarter.append("Q2")
    elif x in ["Jul","Aug","Sep"]:
        quarter.append("Q3")
    else:
        quarter.append("Q4")

# %%
quarter
# Out:
# ['Q3',
#  'Q4',
#  'Q2',
#  'Q1',
#  'Q3',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q1',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q3',
#  'Q1',
#  'Q3',
#  'Q4',
#  'Q2',
#  'Q4',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q1',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Q4',
#  'Q2',
#  'Q4',
#  'Q1',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q1',
#  'Q1',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q1',
#  'Q4',
#  'Q3',
#  'Q4',
#  'Q1',
#  'Q1',
#  'Q3',
#  'Q2',
#  'Q3',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Q3',
#  'Q4',
#  'Q3',
#  'Q1',
#  'Q4',
#  'Q4',
#  'Q3',
#  'Q1',
#  'Q3',
#  'Q4',
#  'Q1',
#  'Q3',
#  'Q1',
#  'Q3',
#  'Q2',
#  'Q1',
#  'Q3',
#  'Q3',
#  'Q2',
#  'Q4',
#  'Q1',
#  'Q2',
#  'Q4',
#  'Q2',
#  'Q3',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q3',
#  'Q4',
#  'Q3',
#  'Q2',
#  'Q3',
#  'Q1',
#  'Q3',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q3',
#  'Q2',
#  'Q4',
#  'Q1',
#  'Q1',
#  'Q4',
#  'Q1',
#  'Q2',
#  'Q1',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q3',
#  'Q1',
# ...

# %%
sales["Qtr"]= pd.Series(quarter)

# %%
sales.head()
# Out:
#    AccountId AccountName Region     Division       City State Tier Month  \
# 0       1116    Account1   West  DIAMONDBACK  PHOENIX W    AZ  Low   Aug
# 1       1116    Account1   West  DIAMONDBACK  PHOENIX W    AZ  Low   Oct
# 2       2391    Account2   East    MINUTEMEN   HARTFORD    CT  Med   Jun
# 3       2391    Account2   East    MINUTEMEN   HARTFORD    CT  Med   Mar
# 4       2397    Account3   East    MINUTEMEN  WORCESTER    MA  Med   Sep
#
#    Sales2015  Sales2016  Units2015  Units2016  TargetAchevied2015  \
# 0       0.00   13208.52        0.0        4.0                0.70
# 1   10500.78   23114.91        3.0        7.0                0.84
# 2       0.00    6627.00        0.0        3.0                1.15
# 3   19881.00   13254.00        9.0        6.0                1.33
# 4    3684.48       0.00        1.0        0.0                1.02
#
#    TargetAchevied2016 Qtr
# 0                1.53  Q3
# 1                1.31  Q4
# 2                1.29  Q2
# ...

# %% [markdown]
# ### 7. Compare Qtr wise sales in 2015 and 2016 in a bar plot

# %%
#grouping data based on "Qtr" to find total sales in 2015 and 2016
sales7 = sales.groupby("Qtr")["Sales2015","Sales2016"].sum()
# Out:
# <ipython-input-25-324635e095dd>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales7 = sales.groupby("Qtr")["Sales2015","Sales2016"].sum()

# %%
sales7
# Out:
#         Sales2015     Sales2016
# Qtr
# Q1   5.485800e+06  6.997953e+06
# Q2   5.390862e+06  7.237361e+06
# Q3   6.164094e+06  7.861546e+06
# Q4   5.713634e+06  7.567868e+06

# %%
sales7.plot(kind="bar")
plt.ylabel("Sales")
plt.title("Quarter wise sales in 2015 and 2016")
plt.show()

# %% [markdown]
# ### 8. Determine the composition of Qtr wise sales in and 2016 with regards to all the Tiers in a pie chart.

# %% [raw]
# #8. Determine the composition of Qtr wise sales in and 2016 with regards to all the Tiers in a pie chart.
# sales8 = sales[sales['Tier']!='Out']
# sales8 = sales8.groupby([...]).aggregate({...})
# sales8 = sales8.round(decimals=0)
# sales8 = sales8.stack() # long to wide data
# sales8 = sales8.unstack(level=0)
# sales8

# %% [raw]
# sales8.plot(kind='pie',
#             labels=['High', 'Low', 'Medium'],
#             colors=['deepskyblue', 'darkorange', 'darkgreen'],
#             autopct='%1.0f%%',
#             fontsize=10,
#             subplots='true',
#             layout=(2,2), #to get a grid
#             figsize=(10,10))
# plt.show()

# %%
sales8 = sales[sales['Tier']!='Out']
sales8 = sales8.groupby(['Tier','Qtr'])['Sales2016'].sum()
sales8 = sales8.round(decimals=0)
sales8 = sales8.unstack(level=1)
sales8
# Out:
# Qtr          Q1         Q2         Q3         Q4
# Tier
# High  3867719.0  4130953.0  4872559.0  4740002.0
# Low    948833.0   890595.0   795178.0   742659.0
# Med   2181402.0  2215814.0  2197058.0  2085207.0

# %%
sales8.plot(kind='pie', 
            labels=['High', 'Low', 'Medium'], 
            colors=['deepskyblue', 'darkorange', 'darkgreen'],
            autopct='%1.0f%%',
            fontsize=10,
            subplots='true',
            layout=(2,2), #to get a grid
            figsize=(10,10))
plt.show()
